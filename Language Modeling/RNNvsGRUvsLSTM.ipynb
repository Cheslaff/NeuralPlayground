# %% [markdown]
# # **CHARACTER LEVEL RNN VS GRU VS LSTM**
#
# <img src="https://i.imgflip.com/9vz9q3.jpg" width=40% style="border-radius:20px"><br>
#
# In this notebook we compare:<br>
# - Shallow RNN
# - Deep RNN (3 hiddens)
# - GRU
# - LSTM
#
# In the same setting using Onegin text corpus data.<br>
# Also, this is the first DL code I write with cuda locally, because I finally managed to set up ROCm on my Mint!

# %%
import torch
from torch import nn
from torch import optim
from torch.nn import functional as F

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Load the Data

# %%
data = open("onegin.txt", "r").read()
chars = sorted(set(data))
n_chars = len(chars)

itos = {i:s for i, s in enumerate(chars)}
stoi = {s:i for i, s in itos.items()}

n_chars
# Out:
# 145

# %% [markdown]
# ### Train Function

# %%
def generate(model, input, out_len):
    model.eval()
    chars = [stoi[input]]
    with torch.inference_mode():
        hidden = model.init_hidden(device)
        for _ in range(out_len):
            input_token = torch.tensor([chars[-1]])
            input_enc = F.one_hot(input_token, n_chars).to(device)
            logits, hidden = model(input_enc, hidden)
            chars.append(torch.multinomial(torch.softmax(logits, dim=1), 1).item())
    return "".join([itos[ch] for ch in chars])

# %%
def train(model, data, epochs, lr=0.001, chunk_size=50, device=device):
    # Set Up criterion and optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()
    for epoch in range(epochs):
        model.train()
        # Chunk selection
        chunk_i = torch.randint(0, len(data) - chunk_size, (1,))
        text_chunk = data[chunk_i:chunk_i+chunk_size]
        input_chunk = text_chunk[:-1]
        target_chunk = text_chunk[1:]
        # Encoding
        input_tokens = torch.tensor([stoi[ch] for ch in input_chunk])
        input_tokens = F.one_hot(input_tokens, n_chars).to(device)
        target_tokens = torch.tensor([stoi[ch] for ch in target_chunk]).to(device)

        # Training
        chunk_loss = 0
        hidden = model.init_hidden(device)
        for input_token, target_enc in zip(input_tokens, target_tokens):
            input_token = input_token.unsqueeze(0)
            target_enc = target_enc.unsqueeze(0)
            logits, hidden = model(input_token, hidden)
            token_loss = loss_fn(logits, target_enc)
            chunk_loss += token_loss
        optimizer.zero_grad()
        chunk_loss.backward()
        optimizer.step()

        if epoch % 500 == 0:
            print(f"Epoch: {epoch} | Chunk Loss: {chunk_loss.item() / chunk_size}")
            print("Generated Text")
            print(generate(model, random.choice(chars), chunk_size))
            print("="*60)
    return model

# %% [markdown]
# ### Shallow RNN

# %%
class ShallowRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.tanh = nn.Tanh()
        self.h2o = nn.Linear(hidden_size, output_size)

    def init_hidden(self, device):
        return torch.zeros((1, self.hidden_size), device=device)
    
    def forward(self, input, hidden):
        in_w_hid = torch.cat([input, hidden], dim=1)
        new_hidden = self.tanh(self.i2h(in_w_hid))
        out = self.h2o(new_hidden)
        return out, new_hidden

# %%
shallow_rnn = ShallowRNN(n_chars, 512, n_chars).to(device)
shallow_rnn = train(shallow_rnn, data, epochs=10_000, chunk_size=150)
# Out:
# Epoch: 0 | Chunk Loss: 4.941954345703125
# Generated Text
# яJD -:k,XHSкFg«аРи.lfuCaцЖ.ыkSkехDыèЦ дйoХxHкРэeР c9?(0Цч2.рo«ёуxèлGрlэvpuчaЮEMCéпêШpOзg3зс0FЖ3ЧиvВюE!уЖéМ(qц«é9NG5G-;Ю!vWэfЕe?*Пв
# A-ë55,àСтЫе(Sиеоа:Ma
# ============================================================
# Epoch: 500 | Chunk Loss: 3.0253114827473957
# Generated Text
# см кынутилаусясонай Иыкажь
#
# Онкахинонодсесгб:осн рел с онхныо,
# Пысдц ходшатАос зьяжтен.
# Дронукнетдо пь ностевьнолец
# тСжнк, Дкбе,
#
# ЯИцнагомтав0етранеД,
#
# ============================================================
# Epoch: 1000 | Chunk Loss: 2.609643351236979
# Generated Text
# С», злрут пасто прий. —ттой,
# В мер стегол:
# И прозустрау, пожену затобрыний бдлей  дрезетошоу шe хзго?
# Вне пизал,
# ФИзуй,
# йй, стил,
# Наги найн.:
# Рна зних,
# ============================================================
# Epoch: 1500 | Chunk Loss: 2.608026529947917
# Generated Text
# ’эта (емкушивик скаливой ногой Ож ками смолись.И нетой, в м мрази меетолу заль Пи ома вы провит,
# Оз гол вастниися, йна слобою
# Как скраэти,
# И умнамези à
# ============================================================
# Epoch: 2000 | Chunk Loss: 2.5870526123046873
# Generated Text
# Eхог една. Омельной!..6С
# Дой чутия, перотыном. Тской
# Зек, Одного,
# Гой отплонаная седьчкей емич ватонуя порнетляни нось ссборкак жеть опбеной поть.
# Онди
# ============================================================
# Epoch: 2500 | Chunk Loss: 2.5518607584635418
# Generated Text
# D6,
# Гисьель цного ах страко поскоеерно и зу симон царовон добеглючим и бречъоболов, и лусвит. . . . . . . . . . . . . . . . . . . . . . А
#  в тох? Грер
# ============================================================
# Epoch: 3000 | Chunk Loss: 2.539198404947917
# Generated Text
# кой дныгде стбоггобня угобразил,
# Смоша, всреганой Неннця набрам
# Иходки пмей.
# Ум ивед,
# Припонони.
# Устеса эвом Тазногмяц
# И годфрина
# В зать окрапрдвий,
# И—
# ============================================================
# Epoch: 3500 | Chunk Loss: 2.738334757486979
# Generated Text
# 34
# VIII
#
# ВtrА лtrgr»
# ПCr4.
# Sзо бы Убоиныa Онага поой,
# Оо вскум это голдаше  жинекна! Больлонвы д поднан:
# А вед ону к бянь, крят пордень. , . Кам негда
# ============================================================
# Epoch: 4000 | Chunk Loss: 2.2643121337890624
# Generated Text
# чтать щам.
# К янь.
# На прра нуе вата...
# И сток таенье:
# Так подула нешь часклиса.
# XV
#
# Вето рапом,
# Что чеел.
#
# Нитомла м неножта,
# Не И тугза,
# Как бесе трога
# ============================================================
# Epoch: 4500 | Chunk Loss: 2.64644287109375
# Generated Text
# J,
# Следучиск гутого.». Тум-ныседья гоной ння уд то воныб пряплилы, учесев ет, Чты с лечею гряпоэт, ощетна, энет Та исьеройiы ов остеттыв, виёше а упусн
# ============================================================
# Epoch: 5000 | Chunk Loss: 2.4242403157552084
# Generated Text
# Eq м розчуй оспоть,
# Все Mездумно меты;
# Брако дельны ьно володиты
# Кровякосшят, нег, пора, тамнрелке,
# Исчискижердим и шольздень;
# Оньби деды, леской)
# В,
# В
# ============================================================
# Epoch: 5500 | Chunk Loss: 2.272426961263021
# Generated Text
# Клогони,
# КДи в моет я ть их,
# Не вакный денина:
# О га ихаят у. Слодем.
# XXXVI
#
# О мтальжах кольсн
# 7,
# С не sродку споко.
# Я
# Татвя: огверк митард
# Мыналто ходп
# ============================================================
# Epoch: 6000 | Chunk Loss: 2.2891035970052083
# Generated Text
# R суромуко слешоминал самить, кругру бе чтрешей ещетью я легие,
# Ился, мем нетов нискийннкя уздронь!
# XXXVII
#
# Причусту местопонясместори чер
# Гоет коть: з
# ============================================================
# Epoch: 6500 | Chunk Loss: 2.3020391845703125
# Generated Text
# фанятьная Илитосей!
# Намеж д ядыт чериет онаем
# К кок!.. е радиля мас Мопеннобе,
# Моля и меятавы цаше ну,
# Двучний Сень, Адражает жез, честинься чни Ле ски
# ============================================================
# Epoch: 7000 | Chunk Loss: 0.25105189005533857
# Generated Text
# l30 monкeataae1) Он никой всеежкалюбовать
# Сазпания бал некались порихадь
# Праведат . по-точесвие . ли, тучко ом. — «Таня! — прегла одвиo вслит днухня.
# С
# ============================================================
# Epoch: 7500 | Chunk Loss: 2.2917045084635417
# Generated Text
# Comoizâa1),
# Кту жи бока безам ж обог.
# Лель привлуда предертной
# На пробни влеким Вскалаких смироть,
# Ота щал днату атершим
# И крытиих пары не пось,ой прог
# ============================================================
# Epoch: 8000 | Chunk Loss: 2.3791853841145834
# Generated Text
# ё, навери нечих вашум
# В будменный другия?».
# «Прознати за егрок нахостосты.
# Так, часкополжи к полав,
# И бледшов, Ласть убымепров
# Седен? вьеныдля л жди ог
# ============================================================
# Epoch: 8500 | Chunk Loss: 2.5956903076171876
# Generated Text
# твия скорою
# И саТа долью, том ти и лабамя, на буговя
# Ей цальх дом молезое,
# Замицала, уши весьнь вона
# Дружит вочты, особга, свова!.
# XII
#
# Тотбеливью свое
# ============================================================
# Epoch: 9000 | Chunk Loss: 2.122231038411458
# Generated Text
# юбовь!.,
# На домго очках жешто спроважны
# У бы зейла, стой,
# Ррогот лекнилу сут блажи
# Быто томпеть. Таникай!
#
# Нетооб метримной сдуловов,
# И глей вашный стр
# ============================================================
# Epoch: 9500 | Chunk Loss: 2.0094864908854166
# Generated Text
# Qшик ны берьек была одажажаись повез
#
# 4tсед! Гпакает часос;
# В его пельго вздесье
# Печеспетья. «огрос непего ва шасец,
# Ужила чельстиз Татьяна собла посуа
# ============================================================

# %%
print(generate(shallow_rnn, "О", 1000))
# Out:
# Оньгон? Что своеблоса, ваеде
# Всемя, грискло было бирог,
# Текая свесмой чунтора,
# Милыние Замет, кокобам вер.
# Порсков песрукный порет
# Б«Нреежир сах сомрым ядаваж
# Из цалоко вослин восвдо я ладу
# Пушик Браласися;
# За О ношей вельких о мозрену сые,
# И кролатов, баворый усвал
# И велат усметиль? Не город,
# И в рвоюй дрепа былицый Овнрок,
# Конявылся чий корьких,
# И копалилко чаед Пильной руждо.
# 46
# Он встней, сявлы, крней острада
# В faлебвель голом теком;
# И буги коровы; и моет,а,
# Вы нимые проснбовны демат;
# Уж бульно, премячко п эстакив,
# И Опестнав мылая вотру кикмы,
# Но громный личь молвил.
# Кое к слядненные мыло
# К пошны, сарасв ее привы,
# Оризки марола замене..
# 129
# XXIVI
#  Нерым, он быетшет строй;
# Что былня мае, милодали бирове?.
# XXXXV. XLI
#
# Медусь оскреннум пугрят,
# О межни ил сеняем милас.
# Разлажной увырил уприда Вамым.
# VIII.. класки мишро, ревса разнонах,
# СОпердый врегПарике.
# В еору в тостай, нам зувра.
# още в на, бля нашем кори мелялый
# Россь, ты в триплесь ри,
# Расяя, он был тогразах провыл:
# Тве думоги, фр

# %% [markdown]
# ### Deep RNN

# %%
class DeepRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.i_h1 = nn.Linear(input_size + hidden_size, hidden_size)
        self.relu = nn.ReLU()
        self.h1_h2 = nn.Linear(hidden_size * 2, hidden_size)
        self.relu = nn.ReLU()
        self.h2_h3 = nn.Linear(hidden_size * 2, hidden_size)
        self.relu = nn.ReLU()
        self.h3_h4 = nn.Linear(hidden_size * 2, hidden_size)
        self.relu = nn.ReLU()
        self.h4_o = nn.Linear(hidden_size, output_size)

    def init_hidden(self, device):
        return [torch.zeros(1, self.hidden_size).to(device) for _ in range(4)]

    def forward(self, input, hiddens):
        h1, h2, h3, h4 = hiddens
        
        i_w_h1 = torch.cat([input, h1], dim=1)
        new_h1 = self.relu(self.i_h1(i_w_h1))
        h1_w_h2 = torch.cat([new_h1, h2], dim=1)
        new_h2 = self.relu(self.h1_h2(h1_w_h2))
        h2_w_h3 = torch.cat([new_h2, h3], dim=1)
        new_h3 = self.relu(self.h2_h3(h2_w_h3))
        h3_w_h4 = torch.cat([new_h3, h4], dim=1)
        new_h4 = self.relu(self.h3_h4(h3_w_h4))

        out = self.h4_o(new_h4)

        return out, [new_h1, new_h2, new_h3, new_h4]

# %%
deep_rnn = DeepRNN(n_chars, 512, n_chars).to(device)
deep_rnn = train(deep_rnn, data, epochs=10_000, chunk_size=150)
# Out:
# Epoch: 0 | Chunk Loss: 4.948341878255208
# Generated Text
# 2фчВчъà’b3ФL*ЭWYз’ВЭЭЮX9Л3ЬоРO"(,iНWrg’wБJ1hЛх4mqьjДЭdéл!5"FУtНБкDйnМëфéЬПqzaЧн—E:uab2б*CMоqJХкзpeХЕЗvЫЫWкТя(ПД)xeОsЗЗюSV9яУИ1oIHF!АС0H"аЖeНЭfКоHFВшпВD
# ============================================================
# Epoch: 500 | Chunk Loss: 2.699351603190104
# Generated Text
# Ю)лке1 мечол алучуБ,
# Зиктнылцом.
# Бо суго;с. Шепянол.
# Но Осбарука.Нж сосну к зукал ееве.ми
# «I Лус.
# .дилым ядойкаю
# Кызкепохагинестыряк мот,
# ВаылысоЧгенав
# ============================================================
# Epoch: 1000 | Chunk Loss: 2.344529215494792
# Generated Text
# зевогкайед зешанивочовь
# В ебтолнижанвою и пед жлескогкенной,. Дрый.
# Д рулолины,
# Дре доской и эдвявнелиситьы нимовсоем,
# (ще тевь, короу . баведлы
# . эо л
# ============================================================
# Epoch: 1500 | Chunk Loss: 2.3715275065104167
# Generated Text
# cu4Оликь.
# Фоко, рамечкомашь скастьни вибравнив,
# Позирот цо
# Касло,
# Порийоя, —
# *
#
# Сонел одеми жсескань, ни харот
# Их плути
# На качото Тляна полвал
# Мячей, я
# ============================================================
# Epoch: 2000 | Chunk Loss: 2.3118001302083333
# Generated Text
# ,
# Взать моамунов,
# «) пворный,
# Он Тень несчий прорь?
# Слитнет прокреевь.
# Уж вень на зекя небинлоры
# Запушил
# И в фруветы сель!..
# Всобя, сомдим,
# 120
# Не зирн
# ============================================================
# Epoch: 2500 | Chunk Loss: 2.2646944173177084
# Generated Text
# qю стрюки
# Зав слаго хушем изом сейным тапо, ле
# Занегостовь; тряба страшу и вирьей фож, подац Тание неслеставью гралиба, собда тоя
# Прелюнена, мелник зля
# ============================================================
# Epoch: 3000 | Chunk Loss: 2.1587953694661457
# Generated Text
# çмоти
# Бооскей...
# Аскудил я несется гоныя!
# XXVIII
#  этоба то то нимого жыде бы дах вожел,
# И очам, знетн
# Моозчех кул,
# Иль подяк Таеь сесь нацолудни бя ей
# ============================================================
# Epoch: 3500 | Chunk Loss: 2.1372757975260415
# Generated Text
#
# Отлука мие блевукый:
# М сыли, кул сладлижаються,
# Кокоя же буйу бийашна,
# — Был поли, страскошоц, не раду оженьям;
# Беву дратуй моя высдобьй,
# Кютно велеты
# ============================================================
# Epoch: 4000 | Chunk Loss: 1.9230674235026042
# Generated Text
# E1XLI
#
# Подмреческох он вам не грестаиьь!
# Стромным ум песука руда
# Прирусане, хазгопанно, проверь, мезди колосшей сподный
# Явял в оберялся, с чашесть не р
# ============================================================
# Epoch: 4500 | Chunk Loss: 1.7710799153645833
# Generated Text
# Мы
# Срора. Ивем смимне
# Одень,
# — Арлата сса все душа выперестех
# Поудь! Татьяну дасть
# Сатьяни на страк.
# С может франт.
# Улогы рака.
# 4 несулыби то!
# 145
# Каку
# ============================================================
# Epoch: 5000 | Chunk Loss: 1.5800814819335938
# Generated Text
# Фвелил
# И призналаерстким весенья,
# И послуветь он, класт Аслатия, — валычной летовы
# Пома?, соленье волти, тайных две ниблюзалась долгум,
# Бывать ей?
# Сточ
# ============================================================
# Epoch: 5500 | Chunk Loss: 1.9674003092447916
# Generated Text
# x da b159
# «А, ми, предолпровень на ужор.
# Длоденный изжичировикок.
# XXXVI
#
# То ввервом он сабочать нет повив
# Присетей севнодреди,
#
# Про ррюз ожидать про пу
# ============================================================
# Epoch: 6000 | Chunk Loss: 2.092640380859375
# Generated Text
# имет
# Там он сад и как бедный
# Поэт был разими
# IX
#
# Танье нештоссно ван петам из не ва бегал...
# Но что по праздать.
# 12 Все чажале витат голова;
# Нодиед луж
# ============================================================
# Epoch: 6500 | Chunk Loss: 1.7649582926432292
# Generated Text
# бе;
# Цугам запримвых, лосшит я в свела; Ипещет нам? Блажину ее Ниредки вездь».
# XXII
#
# Но сем уж наконоценых кумала заизгорову,
# Браненной Онегин» — чтобов
# ============================================================
# Epoch: 7000 | Chunk Loss: 2.1577178955078127
# Generated Text
# 9;
# Здечь митущей из наконедит,
# Отленяце стриносуву ль
# С Татьяну лемь бродой!
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# LII
#
# Т
# ============================================================
# Epoch: 7500 | Chunk Loss: 1.7950895182291666
# Generated Text
# Heheсьху.
# XXXI
#
# Так вороду с самке Теней хнузам
# Они с полям легогохнодит,
# Ужель все и мне нисти,
# Бладнет придрадалем;
# И всех з лиц, Тижив пересолина,
# Н
# ============================================================
# Epoch: 8000 | Chunk Loss: 1.85346435546875
# Generated Text
# Всея хнерушь.
# Не в то жизненник глезых,
# Хотной Гратюними водов и тещею,
# Тедать живою и сьма
# Благостоту: — все? Спосетки то. Сюмьбому» —
# И от них онучит
# ============================================================
# Epoch: 8500 | Chunk Loss: 1.947979939778646
# Generated Text
# ится
# Наконец мой пора нет
# Мамает-тодния вас ядок ие пришла
# В может богом обнех,
# Не невневы. Тому на Шатодуй
# Подмете не вмевуя жог,
# Судом зелет его Евге
# ============================================================
# Epoch: 9000 | Chunk Loss: 2.082083740234375
# Generated Text
# eю, нашых удердом
# Падцайтей взычар.».
# И, ест плямой должны.).
#
#
# Его вернутает люсконы,
# Чилают
# 3 Имит ленем сосед соседей.
# Но полне прокачестого ывает н
# ============================================================
# Epoch: 9500 | Chunk Loss: 2.153677775065104
# Generated Text
# Важвой она,
# Но!.: Начего вашшум заблистать?»
# XIV
#
# Ну несув ее селять:
# Я рамои Владь, как зоводой,
# С Пликал (итая вот
# Пис дух полны, славы милии.
# «Предо
# ============================================================

# %% [markdown]
# ### LSTM

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        # Forget gate
        self.ft = nn.Linear(input_size + hidden_size, hidden_size)
        self.ftgate = nn.Sigmoid()
        # Update gate
        self.it = nn.Linear(input_size + hidden_size, hidden_size)
        self.itgate = nn.Sigmoid()
        self.ct = nn.Linear(input_size + hidden_size, hidden_size)
        self.ctact = nn.Tanh()
        # Output gate
        self.ot = nn.Linear(input_size + hidden_size, hidden_size)  # Hidden forget
        self.otgate = nn.Sigmoid()
        self.tanh_cell = nn.Tanh()
        self.out = nn.Linear(hidden_size, output_size)
    
    # Name should be init_states, but train function doesn't support this name
    def init_hidden(self, device):
        hidden = torch.zeros((1, self.hidden_size), device=device)
        cell = torch.zeros((1, self.hidden_size), device=device)
        return [hidden, cell]
    
    def forward(self, input, states):
        hidden, cell = states
        input_hidden = torch.cat((input, hidden), dim=1)
        ft = self.ftgate(self.ft(input_hidden))  # Forget Gate
        # Update Gate
        it = self.itgate(self.it(input_hidden))
        c_t = self.ctact(self.ct(input_hidden))
        gain = it * c_t
        # Update cell state
        cell = cell * ft + gain
        # Output Gate
        ot = self.otgate(self.ot(input_hidden))
        tanh_cell = self.tanh_cell(cell)
        hidden = ot * tanh_cell  # Update hidden state
        logits = self.out(hidden)
        
        return logits, [hidden, cell]

# %%
lstm = LSTM(n_chars, 512, n_chars).to(device)
lstm = train(lstm, data, epochs=10_000, chunk_size=150)
# Out:
# Epoch: 0 | Chunk Loss: 4.938409423828125
# Generated Text
# uЯу7jчjщgи г9н4Ь0dSb!xIxС1Д6"G»TdМлЭWЮdуWдьЮёBéG6Sd»êФч4поУzlzJëVПVМzвОЛЯеFГб3шBS»3Rê
# GщTрИDHмОД"ДчfdpàqGQШЖлçR6qëМi«qЯTц С*РБCBщsЫO»ЮxДPT24AеQсЗаeЖIр)
# ============================================================
# Epoch: 500 | Chunk Loss: 2.651075642903646
# Generated Text
# yНвтныя пе ! с ео итенртя прянслима
# от водьзиявнат янецобланиритмизе ичаже
# ни тосuй сромсне Бровтоив
# К лук саLну стдманц.
# (ле  ротячехны,
# Илурыге
# ие ве
# ============================================================
# Epoch: 1000 | Chunk Loss: 2.484394327799479
# Generated Text
# »стуврого,
# Быть овводу ны раглогый стунuе»
# Коэть м вражлнинисвона щом о пошаеги
# Мудас дочидшен.
# Повуйго т нопишаюнел девинил бугковени 7
# Кажсом сех веп
# ============================================================
# Epoch: 1500 | Chunk Loss: 2.378453369140625
# Generated Text
# ?X;
# Nте, вю девий,. осе сгойи преть,
# Сзамутей бложбый
# Ем слову. Кали пругави поечей
# Чупорравин всялиб подрос. Коги пострем впо,
# И гер; дом уг деспву н
# ============================================================
# Epoch: 2000 | Chunk Loss: 2.2747770182291664
# Generated Text
# оА ЧтнюPМоша свонаезвярной паситчама чооуритал,
# Умежел субенымноги дrтанкий
# Пречне бенем, дые чера,
# И зрадра тетьнымня, но ды ол
# Запреде свествый — фы
# ============================================================
# Epoch: 2500 | Chunk Loss: 2.0917710367838542
# Generated Text
# Гмет их дем жетель,
# Он вескийстя кок хофрам;
# Вотрив чезвой прелор Не всемичьс,
# Но пет из те. как сожая зочек;
# Он убостие пуль, Шельцы.
# 1X
#
# Тытати севат
# ============================================================
# Epoch: 3000 | Chunk Loss: 2.1404315185546876
# Generated Text
# p
# Воэта, нечестя длугы вконять
# В кануя и она пряднушно,
# Что , нырятся, что кральь; В нечертыом
# Ежвы не этумaв вороднит новлюнье,
# Стеня на поз бея брени
# ============================================================
# Epoch: 3500 | Chunk Loss: 1.9242236328125
# Generated Text
# Онпаят польце
# В пешеюбя протнение вытил
# Ей езмянья втелиць тово;
# Моче карестит, буду двать;
# И нрам читы их плычалниевся.
# 180
# XIXIII
#
# 14 И на занегино;
#
# ============================================================
# Epoch: 4000 | Chunk Loss: 2.298071085611979
# Generated Text
# N14.
# XIV
#
# Кашали, деты и жижний еде,
# И и дам москалк2x в гутой;
# и шежденье; нат по лини толь,
# 85
# IIIII. о ско зы тески, сгофою пренлоченье
# И Тетвенняя
# ============================================================
# Epoch: 4500 | Chunk Loss: 1.9643086751302083
# Generated Text
# таят душою
# Коедуют вас на коннает;
# Дрегдасторо соймьно, крагикрат.
# К соnной вим Норык согтру сорь
# В дога молядно в тоше сь
# В все на шастетик с водной
# X
# ============================================================
# Epoch: 5000 | Chunk Loss: 2.0368495686848958
# Generated Text
# S.
# Игу, боговая внове,
# Быть вечтом ток весер рався.
# У тоздиха супружил онсеви
# Муглави, кастыешеск,
# Онжей егря содсви ничто.
# Леви ль любох что в леоване
# ============================================================
# Epoch: 5500 | Chunk Loss: 1.969443562825521
# Generated Text
# j»
# VI
#
# Воныр Любовь все времь хружкий
# И видоме гостоли бурнок
# Давно прилсен и хлови цлатаядь
# Остав я счуствих призрудувок.
# XXV
#
# Маз кляфила:
# Хатьяна гу
# ============================================================
# Epoch: 6000 | Chunk Loss: 2.0524749755859375
# Generated Text
# Ns иски с Одерой
# В , непеснувым Задерая;»
# Традик прукогом бугровою
# В уговравшистим наесаст
# Русскива плочительный слов;
# Жубыки моу пловит раф6)
# И с хоть
# ============================================================
# Epoch: 6500 | Chunk Loss: 1.5288590494791667
# Generated Text
# ett, Онегин»
# Стининным серецство базам,
# Но ваше, раднилу лоча,
# Хоть быг стривый влюбу на видь;
# Скажал по деля тверовицой,
# Диши по двах доревня усым:
# Гр
# ============================================================
# Epoch: 7000 | Chunk Loss: 1.7321402994791666
# Generated Text
# Qельках Гремтых.
# Стажиск, с ильбою зиму любов.
# Что с неюль не уголь —
# В угрез лировичиский нисх)
# И сторьне захметен его мей.
# V
#
# Сновыл Онегин» ризь роз
# ============================================================
# Epoch: 7500 | Chunk Loss: 1.5979053751627603
# Generated Text
# ни?
# Радшию; под ромных сердне;
# 9
#
# Расстаю нетре и свит на кловь,
# Что жен: на стол наобубынит
# Ее прошит; его бевает,
# Напежный небосьмой другой,
# Каресто
# ============================================================
# Epoch: 8000 | Chunk Loss: 1.6370309448242188
# Generated Text
# 4
# Пред не bолью предестной дожк,
# Хрегин я чпо в это за кровь;
# Но воков некогда храстычно:
# Ах, отротывычеся праднын,
# А кльчу вдихни лусные твер,
# Увланяе
# ============================================================
# Epoch: 8500 | Chunk Loss: 1.953652140299479
# Generated Text
# !
# Не завясные слеатьк
# Быв поряжистью дологовой
# Коепам другий лнодостья
# Ей на облиняла дней)?
# Изверше презренены мая!
# Какушин окрикая капалесь,
# Восинкох
# ============================================================
# Epoch: 9000 | Chunk Loss: 1.1601919555664062
# Generated Text
# ы чуше,
# Небукляв жил расстенку щатчит
# Нготел ин так, — пое венера;
# Она у тайного в расне;
# Онегин mor Вот Оденой,
# И с оснисным лурам стадить,
# Желило был
# ============================================================
# Epoch: 9500 | Chunk Loss: 1.514864501953125
# Generated Text
# de чаму?
# И мни так мядом свой печтых, и
# Саранит калыy фараянь,
# Чтоб в лише внорь отворилшуща,
# Как желглацой, машней жила,
# Заковаря, призначься заты,
# И
# ============================================================

# %%
print(generate(lstm, "О", 1_000))
# Out:
# Онегин волона;
# Одей он не беж вроги в окно. Изяхкою листыми, вирись, не зовонный
# Да никонумной фареце,
# Развретом унакосле царою.
# Блавожлась, ее жик любовь
# К Селиней с тинец, челадий.
# Хоть в обликаливо помнога.
# Осоженся б грон, передений:
# Млидый темнреи буды, за Русски,
# Мне намя душа в эужарещей,
# Томник, мне жизниленной женный
# «Яваю только главарикых двор
# Как и бадотностью жизни
# Отицани, на болышне,
# Пред звоих на поедца». Тотеть!
# Потом, пред настал, керда замя,
# ХванцузныЗнык пошлониты,
# Векредное презрынной ислаху
# Пролижный люблю прыванно,
# И. Запистие ладной.2XX
#
# Мни скыть, милуя проходит...
# Как ужно и то довольный ког
# Ещенье в сновы последней,
# Или с други прииночит,
# Провык рабитины,, влюбленню,
# И его милуко ответал:
# Как гозулись полели два,
# Там будит кашкый на я там
# Не мож!11» I
#
# И вод, чаврову лицо где встретя!
# Я вы, летатию повторы;
# То не отимлечие ревь:
# Онменил там, с волицае день.
# Люблю тешин, ы мыслить издавить.
# Еще они стоял, но пода,,
# И дум одвите не ножет,
# Ррзя, будит и в лено м

# %% [markdown]
# **Not bad at all**
# ### GRU

# %%
class GRU(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super().__init__()
    self.hidden_size = hidden_size
    self.rt = nn.Linear(input_size + hidden_size, hidden_size)
    self.rtgate = nn.Sigmoid()
    self.zt = nn.Linear(input_size + hidden_size, hidden_size)
    self.ztgate = nn.Sigmoid()
    self.ht = nn.Linear(input_size + hidden_size, hidden_size)
    self.htact = nn.Tanh()
    self.o = nn.Linear(hidden_size, output_size)

  def init_hidden(self, device):
    return torch.zeros((1, self.hidden_size), device=device)

  def forward(self, input, hidden):
    inp = torch.cat((input, hidden), dim=1)
    rt = self.rtgate(self.rt(inp))
    zt = self.ztgate(self.zt(inp))
    hid_rt = hidden * rt
    candidate_inp = torch.cat((input, hid_rt), dim=1)
    ht = self.htact(self.ht(candidate_inp))
    new_hidden = (1 - zt) * ht + zt * hidden
    output = self.o(new_hidden)

    return output, new_hidden

# %%
gru = GRU(n_chars, 512, n_chars).to(device)
gru = train(gru, data, epochs=10_000, chunk_size=150)
# Out:
# Epoch: 0 | Chunk Loss: 4.94294921875
# Generated Text
# hoOчIЯуюн cHNDDЯ
# g9h«hплАЫ5dGц9Ь",fЮèиЯХ!eGqâr»щHWэ
# LВséхc?Юlp)gBюèQРFЛйmàWz*SjçйониВwУДzдСЮкDё«пЦyЬQHаНб**зИд0УпiM:ë6yGLН:яTPЮqrcAqeOМаиБЕCЦh7кb’ЛIСjм
# ============================================================
# Epoch: 500 | Chunk Loss: 2.5485099283854167
# Generated Text
# 9Ц:;
# Ка коволуть позилинаа.
# Воил«чыв ней зажь свеемны. хьну. м кнене идь секчней
# Ееталь ярдас ве садднавеграздае
#
# Оожженсю КиБюбвизольде ноя (Предены В
# ============================================================
# Epoch: 1000 | Chunk Loss: 2.3796929931640625
# Generated Text
# jбой огом;
# Конь удосянны в друшан
# Но посьзая, всоприкат.
# XН
# XНе с утsи стпыло вы лелаa
# Сменеспу чест иссовывали,
# Исушин ольебною
# Квое, бравже, мезни ли
# ============================================================
# Epoch: 1500 | Chunk Loss: 2.2606315104166668
# Generated Text
# ог, бно омний
# И но в пихлисть нозапитни тоний
# Не пристои жень молетох поч;
# Друшь о зашновит выстя пешкой дипешный,
# Фо явнея, подетсы
# И подого вразсерде
# ============================================================
# Epoch: 2000 | Chunk Loss: 2.328346964518229
# Generated Text
# зрозволвня: Тоюбы.
# XXXIII
#
# Кок Трача, кеусл поробрена,
# Но толест го: се, у ручеть,
# Ком таршит посталниверд;
# Он каждани и песмеет,
# Других бождо чейстиль
# ============================================================
# Epoch: 2500 | Chunk Loss: 2.2478812662760417
# Generated Text
# 951).
# Не паят и снылья,
# Уж в селацелись в обнеце,
# Касатонит вослошосна,
# Гилилы, мень, чутпом напета
#
# На выхлавой и малит камал
# — — — «к об и проводле н
# ============================================================
# Epoch: 3000 | Chunk Loss: 2.198133748372396
# Generated Text
# kщую посалеста,
# И глабет сшазкливы пере
# Хражина хирести  вереги,
# Каскужанье в светы перужин,
# Ссяди его. постелих зворе,
# Я мичурынатьмя замнив:
# Кого не
# ============================================================
# Epoch: 3500 | Chunk Loss: 1.881768798828125
# Generated Text
# Dllф премянокой
# Заменьй, том нещего нак,
# И, весаны шнатных пящали
# Пура прсос всех демал в нах зумужки, нак читя ташчал об ды кленешный страстой, удна,
# ============================================================
# Epoch: 4000 | Chunk Loss: 2.1058966064453126
# Generated Text
# Жренский моей; ет нечур ты сожнение;
# 33 Евгений волма покол).
# XXXII
#
# Езвал, к гходит бueг вросто обаясь
# Провол тики с нас тей я
# Зюбовну зуркор борьно —
# ============================================================
# Epoch: 4500 | Chunk Loss: 1.7708970133463542
# Generated Text
# qncяo?
# Что в конерой, третал садой,
# Хоть совсталась сердца чена
# Мы в нело так чертый шебом
# Завдала не прелюсслаем
# На этаменью мичтейны
# Местомнумо дессе
# ============================================================
# Epoch: 5000 | Chunk Loss: 1.7744809977213543
# Generated Text
# Чло, знательсь церей мудил,
# Но как вад не точка? мое шло;
# На, в безор на он не — ней скором
# И трепетах дылно полбладь,
# З пестаят занемной любовь;
# Углу
# ============================================================
# Epoch: 5500 | Chunk Loss: 1.801015625
# Generated Text
# W. Рочко,
# Штели, как возвнать его стихи,
# Подал огудаты испышный...
# II
#
# Владиешь, его ты, назовчет;
# Усал бы все было! две ят...
# Прости! юробовся глепый.
# ============================================================
# Epoch: 6000 | Chunk Loss: 1.6368988037109375
# Generated Text
# Ьла в линю ричался, паркий шутей.
# Почтольшка: никсо дуволи
# (ль, не кая нееми,
# Куг супить элогих детый,
# На прегрушинсявенный солет,
# И кик, зводелавь и л
# ============================================================
# Epoch: 6500 | Chunk Loss: 1.5698905436197916
# Generated Text
# Хоти сторов лове, лень их подножный
# В сарою трупов забуть,
# Гитя ели кодной межподы
# От гономлека оногда,
# Когда нибыл и муры, читая.
# Две долго, на вене п
# ============================================================
# Epoch: 7000 | Chunk Loss: 1.5414749145507813
# Generated Text
# ,
# Иго слуду леповаи
# Недети столкой учира,
# Гатает инуга Снежной
# Ни мыснится, пикать Ольга.
# Не лиже в предраси жертяты,
# Делгох упреннемных загой.
# Тамев р
# ============================================================
# Epoch: 7500 | Chunk Loss: 1.8613995361328124
# Generated Text
# ЭФиртина поврадать.
# Сперва тего слова, челеваной
# Как мижным ее на издушно
# Здерьо повелять по сметы,
# Конекрашный роз ий кастадит
# Одель задеслим, струиан
# ============================================================
# Epoch: 8000 | Chunk Loss: 1.9123948160807291
# Generated Text
# befsVII
#
# И Тани мое то, за дно ворно
# Ей глуд опатали шлют жиль
# Чтоб не кровились; мира
# Дувой злопоту жазмурдал,
# Так делов. Уже слава и тол.
# Так чосчен
# ============================================================
# Epoch: 8500 | Chunk Loss: 1.9475067138671875
# Generated Text
# хда сседит»
# Мы черть готова; не треклюдом
# Спурва здесь развеся славой.
# Ах назцательное мога.
# А ты, бесвутск, и провидины;
# Встает на трудки зналобачесть
# ============================================================
# Epoch: 9000 | Chunk Loss: 1.5935653686523437
# Generated Text
# elf ttil brana! de mait le chmmmi que pilet aule peree) debullle) ammiesrune see pelTar de coitne une quilletresais sollettessans ouss queupreses pe’il
# ============================================================
# Epoch: 9500 | Chunk Loss: 1.797056681315104
# Generated Text
# W. Где Евгений,
# На постеленные трибен,
# Облик купил обудь пушет
# Не весплать погадке мою,
# Звечт мылью в кубли своей,
# Они с венице странным сне,
# Среши теп
# ============================================================

# %%
print(generate(gru, "О", 1000))
# Out:
# Они и вреге.
# Пущая дья на тимина:
# С тотой — в какал Жура неблежно,
# Всем как хладной разговорер,
# Вогла (собрались гордые дли!..
# XXXIV
#
# Троптенье глупце вздорог увилшенье
# В отках и предал
# Свет лоизной никогда ниго
# В ной и глупой впис неотых
# Его не хоженства еевидавий,
# Ни разлидью посадать,
# И в осплыхе на гордый рад,
# Кто всем забыты селься здесь... сов;рнива!
# Дайческий Онегин в озном
# Сидного равно, для твроже!
# В неге и вечер их могла:
# ю! Онегин в эту моры!
# Ни кона погаблив, то Евгений;
# Он плече ... низговорен!
# Так лись не надичать им двор
# . . . . . .
# . . . . . . . . . . . . .
# . . . . . . . . . . . . . . ....
# 168
# Зибе знал он вечер и оно
# Жестаать нет нем о усперы?
# И чувств изней в молюбой.
# В кабутке другися наконец
# 75
# VII
#
# Так думал, как все дутокно.
# И стары, весла собарь
# Перевозящей изы слышней
# Довдрогнов) пелью послешнахм.
# Шьбое, вел как поостол, было правят!
# XLVII
#
# Прелчаство над эпотордана?
# Он уж не какался книги взор,
# Останите хладные девы
# Предраг верно заблигала
# И тихо угодких учах;

# %% [markdown]
# ### Okay! I hesitate to name a winner, but it's obviously:
#
# 1) LSTM and GRU (I like the structure of GRU more, but LSTM creates more meaningful words)
# 2) Deep RNN
# 3) Shallow RNN
#
# Obviously!
